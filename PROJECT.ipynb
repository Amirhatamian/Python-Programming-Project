# %% [markdown]
# <a href="https://colab.research.google.com/github/Amirhatamian/Programming-Project/blob/main/PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# creating netflix_movie dataframe
games_df = pd.read_csv('games_details.csv')
teams_df = pd.read_csv('teams.csv')
# Out:
# <ipython-input-28-52469dd69a3a>:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   games_df = pd.read_csv('games_details.csv')

# %%
nba_df
# Out:
#          GAME_ID   TEAM_ID_x TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0       22200477  1610612759               SAS  San Antonio    1629641
# 1       22200477  1610612759               SAS  San Antonio    1631110
# 2       22200477  1610612759               SAS  San Antonio    1627751
# 3       22200477  1610612759               SAS  San Antonio    1630170
# 4       22200477  1610612759               SAS  San Antonio    1630200
# ...          ...         ...               ...          ...        ...
# 713003  11200005  1610612743               DEN       Denver     202706
# 713004  11200005  1610612743               DEN       Denver     202702
# 713005  11200005  1610612743               DEN       Denver     201585
# 713006  11200005  1610612743               DEN       Denver     202389
# 713007  11200005  1610612743               DEN       Denver     201951
#
#             PLAYER_NAME NICKNAME_x START_POSITION COMMENT    MIN  ...  \
# ...

# %%
nba_df.head()
# Out:
#     GAME_ID   TEAM_ID_x TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0  22200477  1610612759               SAS  San Antonio    1629641
# 1  22200477  1610612759               SAS  San Antonio    1631110
# 2  22200477  1610612759               SAS  San Antonio    1627751
# 3  22200477  1610612759               SAS  San Antonio    1630170
# 4  22200477  1610612759               SAS  San Antonio    1630200
#
#       PLAYER_NAME NICKNAME_x START_POSITION COMMENT    MIN  ...  ABBREVIATION  \
# 0  Romeo Langford      Romeo              F     NaN  18:06  ...           SAS
# 1   Jeremy Sochan     Jeremy              F     NaN  31:01  ...           SAS
# 2    Jakob Poeltl      Jakob              C     NaN  21:42  ...           SAS
# 3   Devin Vassell      Devin              G     NaN  30:20  ...           SAS
# 4       Tre Jones        Tre              G     NaN  27:44  ...           SAS
#
#    NICKNAME_y  YEARFOUNDED         CITY        ARENA  ARENACAPACITY  \
# ...

# %%
nba_df.tail()
# Out:
#          GAME_ID   TEAM_ID_x TEAM_ABBREVIATION TEAM_CITY  PLAYER_ID  \
# 713003  11200005  1610612743               DEN    Denver     202706
# 713004  11200005  1610612743               DEN    Denver     202702
# 713005  11200005  1610612743               DEN    Denver     201585
# 713006  11200005  1610612743               DEN    Denver     202389
# 713007  11200005  1610612743               DEN    Denver     201951
#
#             PLAYER_NAME NICKNAME_x START_POSITION COMMENT MIN  ...  \
# 713003  Jordan Hamilton        NaN            NaN     NaN  19  ...
# 713004   Kenneth Faried        NaN            NaN     NaN  23  ...
# 713005     Kosta Koufos        NaN            NaN     NaN  15  ...
# 713006   Timofey Mozgov        NaN            NaN     NaN  19  ...
# 713007        Ty Lawson        NaN            NaN     NaN  27  ...
#
#         ABBREVIATION  NICKNAME_y  YEARFOUNDED    CITY         ARENA  \
# 713003           DEN     Nuggets       1976.0  Denver  Pepsi Center
# ...

# %%
nba_df.shape
# Out:
# (713008, 43)

# %%
nba_df.describe()
# Out:
#             GAME_ID     TEAM_ID_x     PLAYER_ID            FGM            FGA  \
# count  7.130080e+05  7.130080e+05  7.130080e+05  595572.000000  595572.000000
# mean   2.168985e+07  1.610613e+09  4.022156e+05       3.588597       7.894491
# std    5.676439e+06  8.492493e+00  6.998920e+06       3.036251       5.686454
# min    1.030000e+07  1.610613e+09  1.500000e+01       0.000000       0.000000
# 25%    2.060117e+07  1.610613e+09  2.449000e+03       1.000000       3.000000
# 50%    2.120088e+07  1.610613e+09  2.011710e+05       3.000000       7.000000
# 75%    2.180017e+07  1.610613e+09  2.034730e+05       5.000000      11.000000
# max    5.210021e+07  1.610613e+09  1.962938e+09      28.000000      50.000000
#
#               FG_PCT           FG3M           FG3A        FG3_PCT  \
# count  595572.000000  595572.000000  595572.000000  595572.000000
# mean        0.416857       0.776538       2.184985       0.200886
# std         0.252020       1.224934       2.566354       0.289629
# ...

# %%
nba_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 713008 entries, 0 to 713007
# Data columns (total 43 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   GAME_ID             713008 non-null  int64
#  1   TEAM_ID_x           713008 non-null  int64
#  2   TEAM_ABBREVIATION   713008 non-null  object
#  3   TEAM_CITY           713008 non-null  object
#  4   PLAYER_ID           713008 non-null  int64
#  5   PLAYER_NAME         713008 non-null  object
#  6   NICKNAME_x          62459 non-null   object
#  7   START_POSITION      272383 non-null  object
#  8   COMMENT             117436 non-null  object
#  9   MIN                 595572 non-null  object
#  10  FGM                 595572 non-null  float64
#  11  FGA                 595572 non-null  float64
#  12  FG_PCT              595572 non-null  float64
#  13  FG3M                595572 non-null  float64
#  14  FG3A                595572 non-null  float64
# ...

# %%
nba_df.dtypes
# Out:
# GAME_ID                 int64
# TEAM_ID_x               int64
# TEAM_ABBREVIATION      object
# TEAM_CITY              object
# PLAYER_ID               int64
# PLAYER_NAME            object
# NICKNAME_x             object
# START_POSITION         object
# COMMENT                object
# MIN                    object
# FGM                   float64
# FGA                   float64
# FG_PCT                float64
# FG3M                  float64
# FG3A                  float64
# FG3_PCT               float64
# FTM                   float64
# FTA                   float64
# FT_PCT                float64
# OREB                  float64
# DREB                  float64
# REB                   float64
# AST                   float64
# STL                   float64
# BLK                   float64
# TO                    float64
# PF                    float64
# PTS                   float64
# PLUS_MINUS            float64
# LEAGUE_ID             float64
# TEAM_ID_y             float64
# ...

# %%
nba_df.duplicated().sum()
# Out:
# 7684

# %%
nba_df.corr()
# Out:
#                 GAME_ID  TEAM_ID_x  PLAYER_ID       FGM       FGA    FG_PCT  \
# GAME_ID        1.000000  -0.033009  -0.005462  0.033457  0.036849 -0.011281
# TEAM_ID_x     -0.033009   1.000000   0.005788 -0.005183 -0.002395 -0.000014
# PLAYER_ID     -0.005462   0.005788   1.000000 -0.005845 -0.007148 -0.002367
# FGM            0.033457  -0.005183  -0.005845  1.000000  0.885255  0.494683
# FGA            0.036849  -0.002395  -0.007148  0.885255  1.000000  0.207850
# FG_PCT        -0.011281  -0.000014  -0.002367  0.494683  0.207850  1.000000
# FG3M           0.039905  -0.017791   0.004166  0.480236  0.459740  0.209249
# FG3A           0.051786  -0.021592   0.005886  0.444078  0.576759  0.034563
# FG3_PCT        0.014494  -0.005991   0.003153  0.318643  0.246116  0.300350
# FTM            0.010213  -0.001295  -0.007803  0.474678  0.512225  0.137227
# FTA            0.007402  -0.000344  -0.008163  0.482191  0.509457  0.156223
# ...

# %%
# Assuming the teams_df dataframe has a column called 'CITY' instead of 'TEAM_CITY'
nba_df = pd.merge(games_df, teams_df, left_on='TEAM_CITY', right_on='CITY', how='left')

# %%
nba_df.head()
# Out:
#     GAME_ID   TEAM_ID_x TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0  22200477  1610612759               SAS  San Antonio    1629641
# 1  22200477  1610612759               SAS  San Antonio    1631110
# 2  22200477  1610612759               SAS  San Antonio    1627751
# 3  22200477  1610612759               SAS  San Antonio    1630170
# 4  22200477  1610612759               SAS  San Antonio    1630200
#
#       PLAYER_NAME NICKNAME_x START_POSITION COMMENT    MIN  ...  ABBREVIATION  \
# 0  Romeo Langford      Romeo              F     NaN  18:06  ...           SAS
# 1   Jeremy Sochan     Jeremy              F     NaN  31:01  ...           SAS
# 2    Jakob Poeltl      Jakob              C     NaN  21:42  ...           SAS
# 3   Devin Vassell      Devin              G     NaN  30:20  ...           SAS
# 4       Tre Jones        Tre              G     NaN  27:44  ...           SAS
#
#    NICKNAME_y  YEARFOUNDED         CITY        ARENA  ARENACAPACITY  \
# ...

# %%
nba_df.isnull().sum()
# Out:
# GAME_ID                    0
# TEAM_ID_x                  0
# TEAM_ABBREVIATION          0
# TEAM_CITY                  0
# PLAYER_ID                  0
# PLAYER_NAME                0
# NICKNAME_x            650549
# START_POSITION        440625
# COMMENT               595572
# MIN                   117436
# FGM                   117436
# FGA                   117436
# FG_PCT                117436
# FG3M                  117436
# FG3A                  117436
# FG3_PCT               117436
# FTM                   117436
# FTA                   117436
# FT_PCT                117436
# OREB                  117436
# DREB                  117436
# REB                   117436
# AST                   117436
# STL                   117436
# BLK                   117436
# TO                    117436
# PF                    117436
# PTS                   117437
# PLUS_MINUS            142717
# LEAGUE_ID              26050
# TEAM_ID_y              26050
# MIN_YEAR               26050
# ...
