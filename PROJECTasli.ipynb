# %% [markdown]
# <a href="https://colab.research.google.com/github/Amirhatamian/Programming-Project/blob/main/PROJECTasli.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# creating netflix_movie dataframe
nba_df = pd.read_csv('games_details.csv')
teams_df = pd.read_csv('teams.csv')
# Out:
# <ipython-input-6-52469dd69a3a>:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   games_df = pd.read_csv('games_details.csv')

# %%
nba_df.head()
# Out:
#     GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0  22200477  1610612759               SAS  San Antonio    1629641
# 1  22200477  1610612759               SAS  San Antonio    1631110
# 2  22200477  1610612759               SAS  San Antonio    1627751
# 3  22200477  1610612759               SAS  San Antonio    1630170
# 4  22200477  1610612759               SAS  San Antonio    1630200
#
#       PLAYER_NAME NICKNAME START_POSITION COMMENT    MIN  ...  OREB  DREB  \
# 0  Romeo Langford    Romeo              F     NaN  18:06  ...   1.0   1.0
# 1   Jeremy Sochan   Jeremy              F     NaN  31:01  ...   6.0   3.0
# 2    Jakob Poeltl    Jakob              C     NaN  21:42  ...   1.0   3.0
# 3   Devin Vassell    Devin              G     NaN  30:20  ...   0.0   9.0
# 4       Tre Jones      Tre              G     NaN  27:44  ...   0.0   2.0
#
#    REB  AST  STL  BLK   TO   PF   PTS  PLUS_MINUS
# 0  2.0  0.0  1.0  0.0  2.0  5.0   2.0        -2.0
# ...

# %%
nba_df.tail()
# Out:
#          GAME_ID     TEAM_ID TEAM_ABBREVIATION TEAM_CITY  PLAYER_ID  \
# 668623  11200005  1610612743               DEN    Denver     202706
# 668624  11200005  1610612743               DEN    Denver     202702
# 668625  11200005  1610612743               DEN    Denver     201585
# 668626  11200005  1610612743               DEN    Denver     202389
# 668627  11200005  1610612743               DEN    Denver     201951
#
#             PLAYER_NAME NICKNAME START_POSITION COMMENT MIN  ...  OREB  DREB  \
# 668623  Jordan Hamilton      NaN            NaN     NaN  19  ...   0.0   2.0
# 668624   Kenneth Faried      NaN            NaN     NaN  23  ...   1.0   0.0
# 668625     Kosta Koufos      NaN            NaN     NaN  15  ...   3.0   5.0
# 668626   Timofey Mozgov      NaN            NaN     NaN  19  ...   1.0   2.0
# 668627        Ty Lawson      NaN            NaN     NaN  27  ...   0.0   2.0
#
#         REB  AST  STL  BLK   TO   PF   PTS  PLUS_MINUS
# ...

# %%
nba_df.shape
# Out:
# (668628, 29)

# %%
nba_df.describe()
# Out:
#             GAME_ID       TEAM_ID     PLAYER_ID            FGM            FGA  \
# count  6.686280e+05  6.686280e+05  6.686280e+05  558938.000000  558938.000000
# mean   2.171771e+07  1.610613e+09  4.013434e+05       3.588446       7.896652
# std    5.656289e+06  8.652260e+00  7.225618e+06       3.030466       5.677002
# min    1.030000e+07  1.610613e+09  1.500000e+01       0.000000       0.000000
# 25%    2.070003e+07  1.610613e+09  2.466000e+03       1.000000       3.000000
# 50%    2.120096e+07  1.610613e+09  2.011810e+05       3.000000       7.000000
# 75%    2.180014e+07  1.610613e+09  2.034710e+05       5.000000      11.000000
# max    5.210021e+07  1.610613e+09  1.962938e+09      28.000000      50.000000
#
#               FG_PCT           FG3M           FG3A        FG3_PCT  \
# count  558938.000000  558938.000000  558938.000000  558938.000000
# mean        0.416842       0.778117       2.186019       0.201032
# std         0.251913       1.227615       2.569913       0.289685
# ...

# %%
nba_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 668628 entries, 0 to 668627
# Data columns (total 29 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   GAME_ID            668628 non-null  int64
#  1   TEAM_ID            668628 non-null  int64
#  2   TEAM_ABBREVIATION  668628 non-null  object
#  3   TEAM_CITY          668628 non-null  object
#  4   PLAYER_ID          668628 non-null  int64
#  5   PLAYER_NAME        668628 non-null  object
#  6   NICKNAME           53037 non-null   object
#  7   START_POSITION     255765 non-null  object
#  8   COMMENT            109689 non-null  object
#  9   MIN                558938 non-null  object
#  10  FGM                558938 non-null  float64
#  11  FGA                558938 non-null  float64
#  12  FG_PCT             558938 non-null  float64
#  13  FG3M               558938 non-null  float64
#  14  FG3A               558938 non-null  float64
# ...

# %%
nba_df.dtypes
# Out:
# GAME_ID                int64
# TEAM_ID                int64
# TEAM_ABBREVIATION     object
# TEAM_CITY             object
# PLAYER_ID              int64
# PLAYER_NAME           object
# NICKNAME              object
# START_POSITION        object
# COMMENT               object
# MIN                   object
# FGM                  float64
# FGA                  float64
# FG_PCT               float64
# FG3M                 float64
# FG3A                 float64
# FG3_PCT              float64
# FTM                  float64
# FTA                  float64
# FT_PCT               float64
# OREB                 float64
# DREB                 float64
# REB                  float64
# AST                  float64
# STL                  float64
# BLK                  float64
# TO                   float64
# PF                   float64
# PTS                  float64
# PLUS_MINUS           float64
# dtype: object

# %%
nba_df.duplicated().sum()
# Out:
# 0

# %%
nba_df.corr()
# Out:
#              GAME_ID   TEAM_ID  PLAYER_ID       FGM       FGA    FG_PCT  \
# GAME_ID     1.000000 -0.034193  -0.004770  0.032073  0.035696 -0.011566
# TEAM_ID    -0.034193  1.000000   0.005020 -0.004936 -0.002352 -0.000025
# PLAYER_ID  -0.004770  0.005020   1.000000 -0.005698 -0.006998 -0.002473
# FGM         0.032073 -0.004936  -0.005698  1.000000  0.884811  0.495104
# FGA         0.035696 -0.002352  -0.006998  0.884811  1.000000  0.207637
# FG_PCT     -0.011566 -0.000025  -0.002473  0.495104  0.207637  1.000000
# FG3M        0.040971 -0.020382   0.003886  0.482553  0.461507  0.209441
# FG3A        0.053392 -0.024864   0.005461  0.445941  0.578244  0.035260
# FG3_PCT     0.014945 -0.007205   0.002927  0.321772  0.248690  0.300301
# FTM         0.009810 -0.000047  -0.007574  0.471759  0.509445  0.136666
# FTA         0.006611  0.001390  -0.007927  0.479046  0.506872  0.155110
# FT_PCT     -0.012734  0.003817  -0.006061  0.381720  0.410796  0.159355
# ...

# %%
teams_df
# Out:
#     LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION       NICKNAME  \
# 0           0  1610612737      1949      2019          ATL          Hawks
# 1           0  1610612738      1946      2019          BOS        Celtics
# 2           0  1610612740      2002      2019          NOP       Pelicans
# 3           0  1610612741      1966      2019          CHI          Bulls
# 4           0  1610612742      1980      2019          DAL      Mavericks
# 5           0  1610612743      1976      2019          DEN        Nuggets
# 6           0  1610612745      1967      2019          HOU        Rockets
# 7           0  1610612746      1970      2019          LAC       Clippers
# 8           0  1610612747      1948      2019          LAL         Lakers
# 9           0  1610612748      1988      2019          MIA           Heat
# 10          0  1610612749      1968      2019          MIL          Bucks
# 11          0  1610612750      1989      2019          MIN   Timberwolves
# ...

# %%
teams_df.head()
# Out:
#    LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION   NICKNAME  \
# 0          0  1610612737      1949      2019          ATL      Hawks
# 1          0  1610612738      1946      2019          BOS    Celtics
# 2          0  1610612740      2002      2019          NOP   Pelicans
# 3          0  1610612741      1966      2019          CHI      Bulls
# 4          0  1610612742      1980      2019          DAL  Mavericks
#
#    YEARFOUNDED         CITY                     ARENA  ARENACAPACITY  \
# 0         1949      Atlanta          State Farm Arena        18729.0
# 1         1946       Boston                 TD Garden        18624.0
# 2         2002  New Orleans      Smoothie King Center            NaN
# 3         1966      Chicago             United Center        21711.0
# 4         1980       Dallas  American Airlines Center        19200.0
#
#              OWNER  GENERALMANAGER      HEADCOACH DLEAGUEAFFILIATION
# ...

# %%
teams_df.shape
# Out:
# (30, 14)

# %%
teams_df.shape[0]
# Out:
# 30

# %%
nba_df.head()
# Out:
#     GAME_ID   TEAM_ID_x TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0  22200477  1610612759               SAS  San Antonio    1629641
# 1  22200477  1610612759               SAS  San Antonio    1631110
# 2  22200477  1610612759               SAS  San Antonio    1627751
# 3  22200477  1610612759               SAS  San Antonio    1630170
# 4  22200477  1610612759               SAS  San Antonio    1630200
#
#       PLAYER_NAME NICKNAME_x START_POSITION COMMENT    MIN  ...  ABBREVIATION  \
# 0  Romeo Langford      Romeo              F     NaN  18:06  ...           SAS
# 1   Jeremy Sochan     Jeremy              F     NaN  31:01  ...           SAS
# 2    Jakob Poeltl      Jakob              C     NaN  21:42  ...           SAS
# 3   Devin Vassell      Devin              G     NaN  30:20  ...           SAS
# 4       Tre Jones        Tre              G     NaN  27:44  ...           SAS
#
#    NICKNAME_y  YEARFOUNDED         CITY        ARENA  ARENACAPACITY  \
# ...

# %%
# Assuming that the nba_df dataframe has columns 'GAME_ID', 'TEAM_ID', 'PLAYER_ID', 'NICKNAME', and 'COMMENT'
nba_df.drop(['GAME_ID', 'TEAM_ID', 'PLAYER_ID', 'NICKNAME', 'COMMENT'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-c10ae95e0152> in <module>
#       1 # Assuming that the nba_df dataframe has columns 'GAME_ID', 'TEAM_ID', 'PLAYER_ID', 'NICKNAME', and 'COMMENT'
# ----> 2 nba_df.drop(['GAME_ID', 'TEAM_ID', 'PLAYER_ID', 'NICKNAME', 'COMMENT'], axis=1, inplace=True)
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
# ...

# %%
nba_df

# %%
teams_df.drop(['GAME_ID', 'TEAM_ID_x', 'PLAYER_ID', 'NICKNAME_x', 'COMMENT'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-0d7be06083df> in <module>
# ----> 1 teams_df.drop(['GAME_ID', 'TEAM_ID_x', 'PLAYER_ID', 'NICKNAME_x', 'COMMENT'], axis=1, inplace=True)
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
teams_df

# %%
# Assuming the teams_df dataframe has a column called 'CITY' instead of 'TEAM_CITY'
nba_df = pd.merge(nba_df, teams_df, left_on='TEAM_CITY', right_on='CITY', how='left')

# %%
nba_df.head()
# Out:
#     GAME_ID   TEAM_ID_x TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0  22200477  1610612759               SAS  San Antonio    1629641
# 1  22200477  1610612759               SAS  San Antonio    1631110
# 2  22200477  1610612759               SAS  San Antonio    1627751
# 3  22200477  1610612759               SAS  San Antonio    1630170
# 4  22200477  1610612759               SAS  San Antonio    1630200
#
#       PLAYER_NAME NICKNAME_x START_POSITION COMMENT    MIN  ...  ABBREVIATION  \
# 0  Romeo Langford      Romeo              F     NaN  18:06  ...           SAS
# 1   Jeremy Sochan     Jeremy              F     NaN  31:01  ...           SAS
# 2    Jakob Poeltl      Jakob              C     NaN  21:42  ...           SAS
# 3   Devin Vassell      Devin              G     NaN  30:20  ...           SAS
# 4       Tre Jones        Tre              G     NaN  27:44  ...           SAS
#
#    NICKNAME_y  YEARFOUNDED         CITY        ARENA  ARENACAPACITY  \
# ...

# %%
nba_df.isnull().sum()
# Out:
# GAME_ID                    0
# TEAM_ID_x                  0
# TEAM_ABBREVIATION          0
# TEAM_CITY                  0
# PLAYER_ID                  0
# PLAYER_NAME                0
# NICKNAME_x            650548
# START_POSITION        435558
# COMMENT               589444
# MIN                   115880
# FGM                   115880
# FGA                   115880
# FG_PCT                115880
# FG3M                  115880
# FG3A                  115880
# FG3_PCT               115880
# FTM                   115880
# FTA                   115880
# FT_PCT                115880
# OREB                  115880
# DREB                  115880
# REB                   115880
# AST                   115880
# STL                   115880
# BLK                   115880
# TO                    115880
# PF                    115880
# PTS                   115880
# PLUS_MINUS            141160
# LEAGUE_ID              25837
# TEAM_ID_y              25837
# MIN_YEAR               25837
# ...
